# %%
import pandas as pd

# %%
df = pd.read_csv('euro_2020_players_xtra_stats.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of         Surname      Name Country    Position         Club  Age  SquadNo  \
# 0     Alexander  Schlager     AUT  Goalkeeper         LASK   25        1
# 1         Pavao    Pervan     AUT  Goalkeeper    Wolfsburg   33       12
# 2        Daniel  Bachmann     AUT  Goalkeeper      Watford   26       13
# 3       Andreas     Ulmer     AUT    Defender     Salzburg   35        2
# 4    Aleksandar  Dragović     AUT    Defender   Leverkusen   30        3
# ..          ...       ...     ...         ...          ...  ...      ...
# 616       Rubin   Colwill     WAL  Midfielder      Cardiff   19       25
# 617     Matthew     Smith     WAL  Midfielder    Man. City   21       26
# 618       Tyler   Roberts     WAL     Forward        Leeds   22        9
# 619      Gareth      Bale     WAL     Forward  Real Madrid   31       11
# 620     Kieffer     Moore     WAL     Forward      Cardiff   28       13
#
# ...

# %%
df.sort_values(by='Goals', ascending=False)
# Out:
#        Surname       Name Country    Position             Club  Age  SquadNo  \
# 46      Romelu     Lukaku     BEL     Forward   Internazionale   28        9
# 99      Patrik     Schick     CZE     Forward       Leverkusen   25       10
# 272     Manuel  Locatelli     ITA  Midfielder         Sassuolo   23        5
# 284       Ciro   Immobile     ITA     Forward            Lazio   31       17
# 384  Cristiano    Ronaldo     POR     Forward         Juventus   36        7
# ..         ...        ...     ...         ...              ...  ...      ...
# 223      Serge     Gnabry     GER  Midfielder           Bayern   25       10
# 224      Jonas    Hofmann     GER  Midfielder  Mönchengladbach   28       13
# 225      Jamal    Musiala     GER  Midfielder           Bayern   18       14
# 226    Florian    Neuhaus     GER  Midfielder  Mönchengladbach   24       17
# 0    Alexander   Schlager     AUT  Goalkeeper             LASK   25        1
#
# ...

# %%
df.sort_values(by='GoalsConceded', ascending=False)
# Out:
#       Surname         Name Country    Position             Club  Age  SquadNo  \
# 545     Çakır      Uğurcan     TUR  Goalkeeper      Trabzonspor   25       23
# 156     Lukas     Hradecky     FIN  Goalkeeper       Leverkusen   31        1
# 596     Danny         Ward     WAL  Goalkeeper        Leicester   27       12
# 78      Tomáš       Vaclík     CZE  Goalkeeper          Sevilla   32        1
# 491     Robin        Olsen     SWE  Goalkeeper             Roma   31        1
# ..        ...          ...     ...         ...              ...  ...      ...
# 212    Marcel  Halstenberg     GER    Defender          Leipzig   29        3
# 213  Matthias       Ginter     GER    Defender  Mönchengladbach   27        4
# 214      Mats      Hummels     GER    Defender         Dortmund   32        5
# 215    Niklas         Süle     GER    Defender           Bayern   25       15
# 620   Kieffer        Moore     WAL     Forward          Cardiff   28       13
#
# ...

# %%
df['Club'].value_counts()
# Out:
# Chelsea        16
# Man. City      15
# Bayern         15
# Man. United    12
# Juventus       11
#                ..
# Kortrijk        1
# Dalian Pro      1
# Újpest          1
# Osasuna         1
# Ludogorets      1
# Name: Club, Length: 205, dtype: int64

# %%
df['Club'].value_counts()>10
# Out:
# Chelsea         True
# Man. City       True
# Bayern          True
# Man. United     True
# Juventus        True
#                ...
# Kortrijk       False
# Dalian Pro     False
# Újpest         False
# Osasuna        False
# Ludogorets     False
# Name: Club, Length: 205, dtype: bool

# %%
df['Club'].value_counts()[df['Club'].value_counts()>5].plot.bar()
# Out:
# <AxesSubplot:>
